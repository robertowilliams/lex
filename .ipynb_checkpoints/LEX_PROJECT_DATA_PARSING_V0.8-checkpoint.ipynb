# %% [markdown]
# # LEX PROJECT

# %% [markdown]
# ## NATURAL LANGUAGE PROCESSING PROTOTYPE
#
# ## DATA PARSING
#
# ***
#
# ### Version 0.8
# ### Date: July 27th, 2018

# %% [markdown]
# ### Version Control

# %% [markdown]
# |   Version	|   Description|
# |:---:|:---|
# | 0.8 | Prepared to import txt files generated by Bianca in a copy/paste stile. Using Regex with Vipin example. http://www.vipinajayakumar.com/parsing-text-with-python/|
#
# ***

# %% [markdown]
# #  1. Introduction

# %% [markdown]
# This is a test Jupyter notebook to create a prototype of NLP Classifier to be applied to Legal Documents.
# This notebook has the objective of DATA CLEANING.

# %% [markdown]
# #  2. Library

# %%
import pandas as pd
import re
import os

# personal setup
H = 2

# %% [markdown]
# # 3. Importing file

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'codes',
#  'DATASETS',
#  'electronics',
#  'images',
#  'LEX_PROJECT-V3.ipynb',
#  'LEX_PROJECT_DASK_V1.ipynb',
#  'LEX_PROJECT_DATA_CLEANING_V1.ipynb',
#  'LEX_PROJECT_DATA_CLEANING_V2.1.ipynb',
#  'LEX_PROJECT_DATA_CLEANING_V2.ipynb',
#  'LEX_PROJECT_SCRAPING_V1.ipynb',
#  'OLD',
#  'PackPub',
#  'spam.csv',
#  'stopwords.txt',
#  'Support_Notebooks',
#  'UDEMY']

# %%
# os.mkdir('dataset_test')
os.chdir('DATASETS')
os.listdir()
# Out:
# ['.DS_Store',
#  '1st_phase',
#  '3rdPhase_test_v1.txt',
#  '3rdPhase_test_v2.txt',
#  'import_io']

# %%
# Dictionary with the regex rules.
rx_dict = {
        'order': re.compile(r'(?P<order>^[\d]{1,6}\s-\s\s\n)'),
        'number' : re.compile(r'(?P<number>^[\d]{7}-[\d]{2}\.[\d]{4}\.[\d]{1}\.[\d]{2}\.[\d]{4})'),
        'classe' : re.compile(r'(?P<classe>^Classe/Assunto: .*)\n'),
        'relator' : re.compile(r'(?P<relator>^Relator\(a\): .*)\n'),
        'comarca' : re.compile(r'(?P<comarca>^Comarca: .*)\n'),
        'org_julgador' : re.compile(r'(?P<org_julgador>^.rg.o julgador: .*)\n'),
        'data_julgamento' : re.compile(r'(?P<data_julgamento>^Data do julgamento: .*)\n'),
        'data_publicacao' : re.compile(r'(?P<data_publicacao>^Data de publica..o: .*)\n'),
        'data_registro' : re.compile(r'(?P<data_registro>^Data de registro: .*)\n'),
        'ementa' : re.compile(r'(?P<ementa>^Ementa: .*)\n')
        }

# %%
def _parse_line(line):
    for key, rx in rx_dict.items():
        match = rx.search(line)
        if match:
            return key, match
    # if there are no matches
    return None, None

# %%
def parse(filepath):
    data = []  # create an empty list to collect the data
    # declaring the variables
    """
    order = ''
    number = ''
    classe = ''
    relator = ''
    comarca = ''
    org_julgador = ''
    data_julgamento = ''
    data_publicacao = ''
    data_registro = ''
    ementa = ''
    """

    # open the file and read through it line by line
    with open(filepath, 'r') as file_object:
        line = file_object.readline()
        while line:
            # at each line check for a match with a regex
            key, match = _parse_line(line)
            # extract ordered
            if key == 'order':
                order = match.group('order')
            # extract number
            if key == 'number':
                number = match.group('number')           
            # extract classe
            if key == 'classe':
                classe = match.group('classe')     
            # extract relator
            if key == 'relator':
                relator = match.group('relator')
            # extract comarca
            if key == 'comarca':
                comarca = match.group('comarca')
            # extract org_julgador
            if key == 'org_julgador':
                org_julgador = match.group('org_julgador')
            # extract data_julgamento
            if key == 'data_julgamento':
                data_julgamento = match.group('data_julgamento')
            # extract data_publicacao
            if key == 'data_publicacao':
                data_publicacao = match.group('data_publicacao')
            # extract data_registro
            if key == 'data_registro':
                data_registro = match.group('data_registro')
            # extract ementa
            if key == 'ementa':
                ementa = match.group('ementa')
            # create a dictionary containing this row of data
            row = {
                'Order': order,
                'Number': number,
                'Classe': classe,
                'Relator': relator,
                'Comarca': comarca,
                'Org_julgador': org_julgador,
                'Data_julgamento': data_julgamento,
                'Data_publicacao': data_publicacao,
                'Data_registro': data_registro,
                'Ementa': ementa,
                }
            # append the dictionary to the data list
            data.append(row)
            line = file_object.readline()

        # create a pandas DataFrame from the list of dicts
        data = pd.DataFrame(data)
        # set the School, Grade, and Student number as the index
        #data.set_index(['Order', 'Number', 'Classe', 'Relator', 'Comarca', 'Org_julgador', \
        #                'Data_julgamento', 'Data_publicacao', 'Data_registro', 'Ementa'], inplace=True)
        # consolidate df to remove nans
        #data = data.groupby(level=data.index.names).first()

    return data

# %%
filepath = '3rdPhase_test_v2.txt'

# %%
if __name__ == '__main__':
    data = parse(filepath)
    print(data)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-636097d7f0cb> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     data = parse(filepath)
#       3     print(data)
#
# <ipython-input-10-dd072c45aea1> in parse(filepath)
#      53             # create a dictionary containing this row of data
#      54             row = {
# ---> 55                 'Order': order,
#      56                 'Number': number,
#      57                 'Classe': classe,
#
# UnboundLocalError: local variable 'order' referenced before assignment
