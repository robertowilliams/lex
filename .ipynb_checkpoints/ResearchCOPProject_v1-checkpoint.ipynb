# %% [markdown]
# # Teste

# %%
import os
import poplib
from poplib  import POP3
import urllib
import unidecode
from unidecode import  unidecode
import chardet
import re
import os
import pandas as pd
import sys
import base64

# %%
os.listdir()
# Out:
# ['LEX_EMAIL_FILES',
#  'SCRAPING',
#  'REGEX_EXPRESSIONS_TESTS',
#  '.DS_Store',
#  'LEX_OCT_22_2018.csv',
#  'DASK',
#  'images',
#  'LEX_FINAL_ALG_V1.1.ipynb',
#  'PREDICTION',
#  'DATASETS',
#  'SENDING-EMAIL-V2.0.ipynb',
#  'ROBOT',
#  'RETRIEVING EMAIL-2.0.ipynb',
#  'PREDICTIONS-2.0.ipynb',
#  'SENDING_EMAIL',
#  'SUPPORT_NOTEBOOKS',
#  'RETRIEVING_EMAILS',
#  '.ipynb_checkpoints',
#  'URL.txt',
#  'PARSING',
#  'CLEANING',
#  'LEX_ROBOT_V1.6.ipynb',
#  'ResearchCOPProject_v1.ipynb',
#  'GMAIL',
#  'msgfiles']

# %%
f = open('URL.txt', 'r')
content = f.read()
f.close()
# https://stackoverflow.com/questions/30768056/importing-external-txt-file-in-python

# %%
type(content)
# Out:
# str

# %%
#Pattern
VAR = '\<a\sname\=\\"(?P<Name>.+)\\"\>'
Variables = re.findall(VAR, content)

# %%
len(Variables)
# Out:
# 644

# %%
content
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/html4/DTD/loose.dtd">\n<html><head><title>Health and Retirement Study : HRS 2014 Final Release</title>\n</head><body>\n<table border="0" width="800"><tr><td>\n<pre>\n==========================================================================================\n\nSection J: EMPLOYMENT  (Respondent)\n\n==========================================================================================\n<a name="JHHIDR"></a>\n\nHHID                          HOUSEHOLD IDENTIFICATION NUMBER\n         Section: J     Level: Respondent      Type: Character  Width: 6   Decimals: 0\n\n         .................................................................................\n         18747           000003-959738.  Household Identification Number\n\n\n==========================================================================================\n<a name="JPNR"></a>\n\nPN                            RESPONDENT PERSON IDENTIFICAT
# ...
